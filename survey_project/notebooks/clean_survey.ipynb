# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
csv_path = '../data/raw/music_survey_raw.csv'
df = pd.read_csv(csv_path)
df
# Out:
#             Timestamp                 Email Address What gender are you?  \
# 0   7/7/2026 10:43:01   william.kaden.liu@gmail.com                 Male
# 1   7/7/2026 10:43:16  ema.kaludjerovic23@gmail.com               Female
# 2   7/7/2026 10:43:18          shelyndeli@gmail.com               Female
# 3   7/7/2026 10:43:56         brianqian09@gmail.com                 Male
# 4   7/7/2026 10:44:01          lswagner70@gmail.com                 Male
# 5   7/7/2026 10:44:02    sahilqureshi2008@gmail.com                 Male
# 6   7/7/2026 10:44:13       yuchenwang761@gmail.com                 Male
# 7   7/7/2026 10:44:27          warrensuca@gmail.com                 Male
# 8   7/7/2026 10:44:32   samarthgaggar2010@gmail.com                 Male
# 9   7/7/2026 10:44:43    sportsperson3015@gmail.com                 Male
# 10  7/7/2026 10:45:25    ridhima.v.kapoor@gmail.com               Female
# 11  7/7/2026 10:45:33           mrlijerry@gmail.com                 Male
# ...

# %%
df.isna().head()
# Out:
#     Timestamp  Email Address  What gender are you?  \
# 0       False          False                 False
# 1       False          False                 False
# 2       False          False                 False
# 3       False          False                 False
# 4       False          False                 False
# 5       False          False                 False
# 6       False          False                 False
# 7       False          False                 False
# 8       False          False                 False
# 9       False          False                 False
# 10      False          False                 False
# 11      False          False                 False
# 12      False          False                 False
# 13      False          False                 False
# 14      False          False                 False
# 15      False          False                 False
# 16      False          False                 False
# ...

# %%
df.isna().sum().head()
# Out:
# Timestamp                                                        0
# Email Address                                                    0
# What gender are you?                                             0
# How much do you like rap (music genre) on scale of 1 to 10?      0
# How much do you like pop (music genre) on a scale of 1 to 10?    0
# dtype: int64

# %% [markdown]
# ## There are no null values

# %%
types = df.dtypes
display(types)
# Out:
# Timestamp                                                          str
# Email Address                                                      str
# What gender are you?                                               str
# How much do you like rap (music genre) on scale of 1 to 10?      int64
# How much do you like pop (music genre) on a scale of 1 to 10?    int64
# dtype: object
